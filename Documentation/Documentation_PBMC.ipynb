# %% [markdown]
# # Sex Classifier for Peripheral Blood Mononuclear Cells

# %%
#import packages for analysis
import scanpy as sc
import pandas as pd
import numpy as np
import os
from matplotlib import rcParams
import seaborn as sb
import matplotlib.pyplot as plt
import anndata as ad
from scipy import sparse
from anndata import AnnData
import time
import random
import xgboost as xgb
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
import scrublet as scr
import warnings
import pickle
import sys
sys.path.append('/home/sparikh/Sex_Classifier/')

# %% [markdown]
# ### Import Sex_Classifier_PBMC package which is trained on PBMC datasets

# %%
from Classifier import Sex_Classifier_PBMC as scp

# %% [markdown]
# ### Import test Anndata
# - Test dataset taken from paper published: https://doi.org/10.1016/j.medj.2021.04.008

# %%
adata_test = sc.read('/home/sparikh/Classifier_data/adata_test_kawasaki.h5ad')

# %% [markdown]
# ### Run the sex_classifier_pbmc function on the Test Anndata
# #### Classifies peripheral blood mononuclear cells into males and females based on the count matrix obtained from single cell RNA sequencing experiments.
# - The function takes as argument the test Anndata
# - The prediction column is appended to the test Anndata obs dataframe.
# - If the Anndata contains male/female sex labels, the function also gives the accuracy score
# - In case of sex labels being present, the user can set the *class probability cutoff value* to categorize the classification into: True Positive, True Negative, False Positive and False Negative
# - The accuracy score for males and females is calculated
# - The function ends with ROC-AUC Curve

# %%
scp.sex_classifier_pbmc(adata_test)
# Out:
# Initializing
# Imported Essentials
# Anndata Modified For The Model
# Sex Prediction Complete
# Adding Columns to the Anndata
# The accuracy_score for males for trained model is 0.9313881089000122
# The accuracy_score for females for trained model is 0.9666758374028475
# Prediction Completed
# --- 12 secs ---

# %%
#PCA analysis
sc.pp.pca(adata_test)
#Normalize the data to 10000 reads per cell
sc.pp.normalize_total(adata_test, target_sum=1e4)
#Log tranform the data
sc.pp.log1p(adata_test)

# %% [markdown]
# ### The misclassified function of the package returns a dataframe and works on **test Anndata with Sex Annotation**
# #### *Cell type annotation is an important part of the function. Since the package has been optimized for PBMCs, the function includes performing annotation of PBMCs by utilizing MACA tool if the dataset is not annotated by the user*
#
# - The function works by comparing the sex annotated anndata to the predictions added by the sex_classifier
# - The returned dataframe gives information about the number of correctly and incorrectly classified cells according to the cell type annotation
# - The dataframe attempts to explain why certain cells were misclassified, such as if they have low quality, are doublets, or have a high mitochondiral fraction
# - The function allows the user to specify custom values for the minimum number of counts, minimum number of genes, and mitochondiral fraction as arguments, rather than using the default values
# - It allows the user to set custom values for the cutoff for the class prediction probability

# %%
df = scp.misclassified(adata_test, min_ncounts=1100, min_genes=300, min_mtfrac=0.04)
# Out:
# Initializing
# (53651, 30)
# (53651, 30)
# Annotation Complete
# Low quality cells detected and dataframe created
# --- 3 mins ---

# %%
df
# Out:
#                                    Annotation  Number_Cells  Perc_Total  \
# 0                                CD4+ Naive T        7838.0   14.611412
# 1                            CD4+ Cytotoxic T        1812.0    3.377887
# 2                         Intermediate B cell        3057.0    5.698786
# 3                              CD14+ Monocyte        5859.0   10.922208
# 4                                Naive B cell       11351.0   21.160263
# 5                     CD56-dim Natural Killer        3311.0    6.172287
# 6                      CD4+ Effector Memory T        1322.0    2.464441
# 7                                CD8+ Naive T        6454.0   12.031393
# 8                       CD4+ Central Memory T        8190.0   15.267602
# 9                               gamma-delta T        1080.0    2.013310
# 10                             CD16+ Monocyte        1367.0    2.548329
# 11              Conventional Dendritic Cell 2         110.0    0.205059
# 12                                Plasmablast         646.0    1.204258
# 13                Plasmacytoid Dendritic Cell         112.0    0.208788
# 14                             Erythroid cell         661.0    1.232220
# 15     Hematopoietic stem and progenitor cell          75.0    0.139813
# 16                                   Platelet         398.0    0.741942
# Total                                   Total       53643.0  100.000000
#
#        Perc_Incorrectly_Classified  Number_Cells_Misclass  Num_Doublets  \
# 0                         0.944118                   74.0           0.0
# 1                         2.207506                   40.0           1.0
# 2                         1.701014                   52.0           4.0
# 3                        21.505376                 1260.0          26.0
# 4                         2.863184                  325.0           1.0
# 5                         3.956509                  131.0           0.0
# 6                         0.983359                   13.0           1.0
# 7                         0.480322                   31.0           0.0
# 8                         1.343101                  110.0           8.0
# 9                         1.481481                   16.0           0.0
# 10                        3.365033                   46.0           1.0
# 11                        0.909091                    1.0           0.0
# 12                        2.631579                   17.0           0.0
# 13                        3.571429                    4.0           0.0
# 14                       48.562784                  321.0           2.0
# 15                        6.666667                    5.0           2.0
# 16                       51.758794                  206.0           4.0
# Total                   154.931346                 2652.0          50.0
#
#        NCells_High_MT_Frac  NCells_Low_Count/Genes  NCells_Explained_Misclass  \
# 0                      5.0                    22.0                       22.0
# 1                      5.0                     3.0                        4.0
# 2                      5.0                     3.0                        7.0
# 3                      5.0                   187.0                      213.0
# 4                      5.0                    31.0                       32.0
# 5                      5.0                     5.0                        5.0
# 6                      5.0                     1.0                        2.0
# 7                      5.0                     5.0                        5.0
# 8                      5.0                    26.0                       34.0
# 9                      5.0                     0.0                        0.0
# 10                     5.0                     7.0                        8.0
# 11                     5.0                     1.0                        1.0
# 12                     5.0                     9.0                        9.0
# 13                     5.0                     0.0                        0.0
# 14                     5.0                   317.0                      319.0
# 15                     5.0                     0.0                        2.0
# 16                     5.0                    95.0                       99.0
# Total                 85.0                   712.0                      762.0
#
#        NCells_Unexplained_Misclass  Perc_Unexplained  \
# 0                             52.0         70.270270
# 1                             36.0         90.000000
# 2                             45.0         86.538462
# 3                           1047.0         83.095238
# 4                            293.0         90.153846
# 5                            126.0         96.183206
# 6                             11.0         84.615385
# 7                             26.0         83.870968
# 8                             76.0         69.090909
# 9                             16.0        100.000000
# 10                            38.0         82.608696
# 11                             0.0          0.000000
# 12                             8.0         47.058824
# 13                             4.0        100.000000
# 14                             2.0          0.623053
# 15                             3.0         60.000000
# 16                           107.0         51.941748
# Total                       1890.0       1196.050603
#
#        Perc_Unexplained_Total_Pop
# 0                        2.751323
# 1                        1.904762
# 2                        2.380952
# 3                       55.396825
# 4                       15.502646
# 5                        6.666667
# 6                        0.582011
# 7                        1.375661
# 8                        4.021164
# 9                        0.846561
# 10                       2.010582
# 11                       0.000000
# 12                       0.423280
# 13                       0.211640
# 14                       0.105820
# 15                       0.158730
# 16                       5.661376
# Total                  100.000000

# %% [markdown]
# ### The ambiguously_classified function of the package also returns a dataframe but works on the **test Anndata without Sex annotation**
# #### *Cell type annotation is an important part of the function. Since the package has been optimized for PBMCs, the function includes performing annotation of PBMCs by utilizing MACA tool if the dataset is not annotated by the user*
#
# - The function works to identify ambiguously classified cells determined by the custom value set for the cutoff for the class prediction probability specified by the user
# - The default cutoff value is set to 0.85
# - The returned dataframe is built under the assumption that cells with class probability lower than the cutoff are 'incorrectly' classified and vice versa
# - The returned dataframe gives information about the number of 'correctly' and 'incorrectly' classified cells according to the cell type annotation
# - The dataframe attempts to explain why certain cells were misclassified, such as if they have low quality, are doublets, or have a high mitochondiral fraction
# - The function allows the user to specify custom values for the minimum number of counts, minimum number of genes, and mitochondiral fraction as arguments, rather than using the default values

# %%
adata_test.obs.drop('Sex', axis=1, inplace=True)
df_ambiguously_classified = scp.ambiguously_classified(adata_test, class_prob_cutoff=0.85)
# Out:
# Initializing
# Low quality cells detected and dataframe created
# --- 0 mins ---

# %%
df_ambiguously_classified
# Out:
#                                    Annotation  Number_Cells  Perc_Total  \
# 0                                CD4+ Naive T        7838.0   14.611412
# 1                            CD4+ Cytotoxic T        1812.0    3.377887
# 2                         Intermediate B cell        3057.0    5.698786
# 3                              CD14+ Monocyte        5859.0   10.922208
# 4                                Naive B cell       11351.0   21.160263
# 5                     CD56-dim Natural Killer        3311.0    6.172287
# 6                      CD4+ Effector Memory T        1322.0    2.464441
# 7                                CD8+ Naive T        6454.0   12.031393
# 8                       CD4+ Central Memory T        8190.0   15.267602
# 9                               gamma-delta T        1080.0    2.013310
# 10                             CD16+ Monocyte        1367.0    2.548329
# 11              Conventional Dendritic Cell 2         110.0    0.205059
# 12                                Plasmablast         646.0    1.204258
# 13                Plasmacytoid Dendritic Cell         112.0    0.208788
# 14                             Erythroid cell         661.0    1.232220
# 15     Hematopoietic stem and progenitor cell          75.0    0.139813
# 16                                   Platelet         398.0    0.741942
# Total                                   Total       53643.0  100.000000
#
#        Perc_Incorrectly_Classified  Number_Cells_Misclass  Num_Doublets  \
# 0                         3.878540                  304.0           2.0
# 1                         7.505519                  136.0           9.0
# 2                         6.280667                  192.0           5.0
# 3                        38.436593                 2252.0          36.0
# 4                        10.395560                 1180.0          12.0
# 5                        25.309574                  838.0           7.0
# 6                         5.143722                   68.0           1.0
# 7                         2.060738                  133.0           0.0
# 8                         5.958486                  488.0          18.0
# 9                         5.833333                   63.0           7.0
# 10                       14.703731                  201.0           3.0
# 11                        2.727273                    3.0           0.0
# 12                        8.978328                   58.0           1.0
# 13                        5.357143                    6.0           0.0
# 14                       88.502269                  585.0           7.0
# 15                        9.333333                    7.0           2.0
# 16                       94.723618                  377.0           6.0
# Total                   335.128428                 6891.0         116.0
#
#        NCells_High_MT_Frac  NCells_Low_Count/Genes  NCells_Explained_Misclass  \
# 0                      5.0                    46.0                       48.0
# 1                      5.0                     4.0                       13.0
# 2                      5.0                    10.0                       15.0
# 3                      5.0                   268.0                      304.0
# 4                      5.0                    88.0                      100.0
# 5                      5.0                     7.0                       14.0
# 6                      5.0                     3.0                        4.0
# 7                      5.0                    10.0                       10.0
# 8                      5.0                    44.0                       62.0
# 9                      5.0                     2.0                        9.0
# 10                     5.0                    11.0                       14.0
# 11                     5.0                     2.0                        2.0
# 12                     5.0                    17.0                       18.0
# 13                     5.0                     0.0                        0.0
# 14                     5.0                   578.0                      585.0
# 15                     5.0                     1.0                        3.0
# 16                     5.0                   149.0                      155.0
# Total                 85.0                  1240.0                     1356.0
#
#        NCells_Unexplained_Misclass  Perc_Unexplained  \
# 0                            256.0         84.210526
# 1                            123.0         90.441176
# 2                            177.0         92.187500
# 3                           1948.0         86.500888
# 4                           1080.0         91.525424
# 5                            824.0         98.329356
# 6                             64.0         94.117647
# 7                            123.0         92.481203
# 8                            426.0         87.295082
# 9                             54.0         85.714286
# 10                           187.0         93.034826
# 11                             1.0         33.333333
# 12                            40.0         68.965517
# 13                             6.0        100.000000
# 14                             0.0          0.000000
# 15                             4.0         57.142857
# 16                           222.0         58.885942
# Total                       5535.0       1314.165563
#
#        Perc_Unexplained_Total_Pop
# 0                        4.625113
# 1                        2.222222
# 2                        3.197832
# 3                       35.194219
# 4                       19.512195
# 5                       14.887082
# 6                        1.156278
# 7                        2.222222
# 8                        7.696477
# 9                        0.975610
# 10                       3.378500
# 11                       0.018067
# 12                       0.722674
# 13                       0.108401
# 14                       0.000000
# 15                       0.072267
# 16                       4.010840
# Total                  100.000000

# %% [markdown]
# ### The plot_avg_gene_expression function plots the average gene expression of highly expressed genes in Groups
# - The heatmap plots the average gene expression of highly expressed genes in all four groups: Correct Females and Incorrect Females, Correct Males and Incorrect Males
# - The genes that show highly expression are calculated separately for males and females across correctly classified and incorrectly classified cells
# - The function helps in understanding how the classifier classifies the cells based on the genes expressed in different cell types

# %%
plots = scp.plot_avg_gene_expression(adata_test)
# Out:
# Computing
# Genes Identified
# Dataframes created
# Plotting
# --- 17 sec ---

# %% [markdown]
# - The 20 highly expressed genes for all groups are first stored in a list
# - The mean expression of each gene is calculated across the respective Anndata and stored in a datframe
# - The dataframe is then used to plot the heatmap which is shown above
# - The heatmap shows which genes are expressed in correctly and incorrectly classified groups and the level of expression associated with them, giving a general understanding of this relationship
